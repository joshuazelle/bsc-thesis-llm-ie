# %%
from huggingface_hub.inference_api import InferenceApi
import os

# %%
API_TOKEN = os.getenv("HUGGINGFACE_API_KEY")

# %%
from huggingface_hub import InferenceClient

client = InferenceClient()
response = client.post(
    json={"inputs": "The goal of life is [MASK]."}, model="bert-base-uncased"
)
response.json()

# %%
from huggingface_hub import InferenceApi

inference = InferenceApi(repo_id="bert-base-uncased")
inference(inputs="The goal of life is [MASK].")

# %%
url = "https://api-inference.huggingface.co/models/distilgpt2"

# %%
url = "https://api-inference.huggingface.co/models/mistralai/Mistral-7B-v0.1"

# %%
import requests

# %%
prompt = "why is the lion the king of the jungle?"

# %%
header = {"Authorization": f"Bearer {API_TOKEN}"}

# %%
def query(payload):
    response = requests.post(url, headers=header, json=payload)
    return response.json()

# %%
output = query(
    {
        "inputs": prompt,
    }
)

# %%
output
